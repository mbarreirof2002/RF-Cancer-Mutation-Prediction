# %%
import numpy as np
import pandas as pd
import joblib
from IPython.display import display, clear_output
import ipywidgets as widgets
from sklearn.preprocessing import LabelEncoder

# %%
# Load the trained model
rf = joblib.load('best_random_forest.pkl')

# Load the dataset to extract means for non-editable features
df = pd.read_csv("cosmic_clinvar_processed.tsv", sep="\t")

df1 = pd.read_csv("cosmic_clinvar.tsv", sep="\t")
# Out:
# <ipython-input-26-b29fb8ffc784>:7: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv("cosmic_clinvar.tsv", sep="\t")

# %%
mutation_type_options = [
    '5 prime UTR variant', 'frameshift variant', 'inframe deletion', 'inframe insertion',
    'missense variant', 'protein altering variant', 'splice acceptor variant', 'splice donor variant',
    'splice region variant', 'start lost', 'stop gained', 'stop lost', 'stop retained variant',
    'synonymous variant'
]

somatic_status_options = [
    'Not specified',
    'Reported in another cancer sample as somatic',
    'Variant of unknown origin'
]

gene_list = ['LZTR1', 'FLT4', 'KNSTRN', 'ALDH2', 'HOXA11', 'EPAS1', 'KMT2C',
       'TNFAIP3', 'MYOD1', 'PTK6', 'PIK3R2', 'MAP2K2', 'GNAQ', 'PRCC',
       'HLF', 'RUNX1', 'NCKIPSD', 'MET', 'DDX10', 'MN1', 'SS18L1',
       'CIITA', 'KLK2', 'MLLT6', 'CD28', 'MAP2K4', 'MALT1', 'PAX5',
       'ZBTB16', 'FGFR3', 'A1CF', 'MYC', 'MSN', 'TRIM27', 'SSX1', 'HLA-A',
       'TCL1A', 'VTI1A', 'FBLN2', 'EXT2', 'CDKN1A', 'RGPD3', 'SMARCA4',
       'TCF12', 'PRF1', 'CEBPA', 'FOXP1', 'IKBKB', 'ZNRF3', 'VAV1',
       'BCL9', 'POLQ', 'YWHAE', 'GOLGA5', 'STAG2', 'HIST1H3B', 'PIK3R3',
       'NTHL1', 'KIT', 'KAT6B', 'EP300', 'FGFR4', 'EED', 'MAF', 'LASP1',
       'LIFR', 'CCR4', 'PRKD1', 'TFE3', 'LMO1', 'SMARCE1', 'RAP1GDS1',
       'TRIM24', 'TAL2', 'MYB', 'ROS1', 'LMNA', 'PTEN', 'RBM15', 'SRC',
       'SDHC', 'NFKB2', 'SPEN', 'ID3', 'ZMYM2', 'RHOH', 'SMARCD1',
       'CNOT3', 'FBXO11', 'MYCL', 'EWSR1', 'NDRG1', 'NCOA2', 'DROSHA',
       'BCORL1', 'TSHR', 'SNX29', 'RNF213', 'CTNNA1', 'ZNF479', 'BARD1',
       'HOXA13', 'FUS', 'NOTCH1', 'SDHA', 'ERCC3', 'BAX', 'FADD', 'ELN',
       'CDH17', 'ARHGAP26', 'SETD1B', 'PRRX1', 'SET', 'EPS15', 'HOXA9',
       'SFPQ', 'SH2B3', 'HSP90AA1', 'MYH11', 'NCOA1', 'XPO1', 'SDHB',
       'PTPRD', 'GATA1', 'SLC34A2', 'ARHGEF12', 'CHD2', 'ARHGAP35',
       'KTN1', 'PICALM', 'SYK', 'MAFB', 'PMS1', 'SETD2', 'MUC4', 'JAK3',
       'RAD51B', 'PRPF40B', 'PRKAR1A', 'NUP98', 'PIK3CA', 'CUL3', 'IL2',
       'ETV4', 'PABPC1', 'CSF1R', 'FKBP9', 'RARA', 'BRAF', 'DNAJB1',
       'ITGAV', 'SUZ12', 'CEP89', 'RAP1B', 'FUBP1', 'TFRC', 'TRIM33',
       'MDM4', 'FCGR2B', 'TLX1', 'TENT5C', 'EZR', 'ASPM', 'GRM3', 'AFF3',
       'SHTN1', 'FOXR1', 'FAM135B', 'SMAD2', 'PSIP1', 'OMD', 'LRP1B',
       'ERCC2', 'PDCD1LG2', 'CARS', 'PBRM1', 'AR', 'IRF4', 'IKZF1',
       'MUC6', 'ASXL2', 'SFRP4', 'BRCA1', 'FHIT', 'FNBP1', 'POLD1',
       'PIK3CB', 'CTNNA2', 'COX6C', 'UBR5', 'BRCA2', 'LATS1', 'CLP1',
       'CIC', 'AXIN2', 'VHL', 'CTCF', 'GNA11', 'LEF1', 'COL1A1', 'SMC1A',
       'BCR', 'BRD3', 'EML4', 'MLLT1', 'DNMT3A', 'BCL3', 'FLCN', 'TFG',
       'LMO2', 'FLNA', 'ERBB4', 'NUTM1', 'SOX2', 'TOP1', 'ELK4', 'BCL11B',
       'CDC73', 'CUX1', 'TET1', 'MUC16', 'SRGAP3', 'RBM10', 'MYO5A',
       'LATS2', 'SKI', 'ACSL6', 'BIRC6', 'KIAA1549', 'RECQL4', 'RHOA',
       'PBX1', 'FAM131B', 'RXRA', 'CCNC', 'SOCS1', 'MSH2', 'GLI1',
       'ERBB3', 'PDGFRB', 'BUB1B', 'CLTCL1', 'CTNND2', 'CCND2', 'BTG2',
       'DDX5', 'FANCC', 'FLT3', 'ELL', 'RABEP1', 'PPFIBP1', 'RANBP2',
       'MSI2', 'SBDS', 'PMS2', 'FOXO4', 'QKI', 'SMAD4', 'ARID2', 'NF2',
       'ELF3', 'SIRPA', 'GOPC', 'IKZF3', 'GTF2I', 'HEY1', 'HMGA2',
       'NTRK2', 'XPA', 'PAX3', 'CD79B', 'NFE2L2', 'CCNB1IP1', 'KDSR',
       'ABI1', 'SGK1', 'CDK12', 'SS18', 'TBL1XR1', 'ETV1', 'NSD1',
       'PIK3R1', 'CNBD1', 'FLI1', 'CBFA2T3', 'RNF43', 'MLH1', 'PHOX2B',
       'ACKR3', 'BCL2L12', 'ATR', 'SMARCB1', 'COL3A1', 'BTG1', 'N4BP2',
       'BTK', 'LPP', 'LRIG3', 'SMAD3', 'EZH2', 'PCBP1', 'ZCCHC8', 'ETV5',
       'NR4A3', 'MGMT', 'KEAP1', 'CDX2', 'GNAS', 'SUFU', 'IGF2BP2',
       'ARAF', 'PLCG1', 'AKAP9', 'MLLT3', 'MLF1', 'FAT4', 'HOXD13',
       'HMGA1', 'DCC', 'ITK', 'APC', 'RAD17', 'ATP1A1', 'MAML2', 'ACVR1B',
       'B2M', 'HOXC11', 'POLG', 'CDH10', 'RPL22', 'TMEM127', 'MAP3K13',
       'CBL', 'YAP1', 'FBXW7', 'SPECC1', 'ETNK1', 'SIX1', 'EPHA3', 'FAS',
       'RSPO3', 'HIP1', 'ATM', 'KMT2D', 'TCF3', 'SH3GL1', 'FAT3', 'CANT1',
       'EIF4A2', 'PPM1D', 'FANCF', 'SF3B1', 'SIX2', 'FANCD2', 'CCNE1',
       'DNM2', 'CD274', 'MTOR', 'PRDM1', 'RGS7', 'ARNT', 'DDR2', 'EIF1AX',
       'FGFR1OP', 'HSP90AB1', 'TPR', 'RALGDS', 'SOX21', 'BCL10', 'SPOP',
       'LCP1', 'MDM2', 'NUTM2B', 'RPL10', 'ROBO2', 'PAFAH1B2', 'KCNJ5',
       'TCEA1', 'MAP2K1', 'WNK2', 'ASPSCR1', 'NPM1', 'PHF6', 'MYCN',
       'CDKN1B', 'SETBP1', 'U2AF1', 'MECOM', 'POU5F1', 'LYL1', 'PTPRB',
       'EGFR', 'HNF1A', 'ZNF331', 'ISX', 'MSH6', 'RAF1', 'FOXA1', 'RRAS2',
       'CYSLTR2', 'FANCE', 'FSTL3', 'BAZ1A', 'APOBEC3B', 'GSK3B', 'CASP9',
       'DGCR8', 'FAM47C', 'KNL1', 'CHD4', 'CRTC1', 'PER1', 'CALR', 'WT1',
       'CHST11', 'ZRSR2', 'NCOR2', 'WAS', 'MED12', 'ALK', 'CTNND1',
       'MAP3K1', 'COL2A1', 'DAXX', 'PTPN13', 'GAS7', 'FAT1', 'NCOA4',
       'LSM14A', 'AKT1', 'BCL7A', 'BCL9L', 'TERT', 'PCM1', 'SMO', 'ACVR1',
       'TFEB', 'HOXD11', 'CD79A', 'CDKN2C', 'TAL1', 'CREBBP', 'CLTC',
       'JAZF1', 'KAT7', 'STRN', 'BRD4', 'SALL4', 'CBLB', 'KDR', 'MYH9',
       'TNFRSF17', 'MLLT11', 'CTNNB1', 'ERCC5', 'NF1', 'RAD51C', 'PTPRK',
       'MITF', 'HIST1H4I', 'ZNF429', 'PLAG1', 'CASP3', 'AFF1', 'KDM5C',
       'CCND3', 'KLF4', 'LHFPL6', 'IL6ST', 'KAT6A', 'CNTRL', 'TNRC18',
       'RUNX1T1', 'DDX3X', 'CXCR4', 'TMPRSS2', 'FOXO3', 'SEPT5', 'CDKN2A',
       'NTRK1', 'ERCC4', 'ARID1A', 'LARP4B', 'PALB2', 'ATF1', 'CPEB3',
       'TRIP11', 'TLX3', 'NAB2', 'AFF4', 'TP63', 'CCDC6', 'EBF1', 'RPN1',
       'MNX1', 'TBX3', 'DDX6', 'ATRX', 'FH', 'CASP8', 'JAK1', 'CNTNAP2',
       'H3F3A', 'S100A7', 'BLM', 'TRRAP', 'MUC1', 'PTPN11', 'LCK', 'JAK2',
       'AKT2', 'NUMA1', 'NFATC2', 'FANCA', 'GATA3', 'SDHD', 'CREB1',
       'PTPN6', 'ABL2', 'KLF6', 'KMT2A', 'DDIT3', 'DCAF12L2', 'IL21R',
       'OLIG2', 'NCOR1', 'NONO', 'RAD50', 'FOXL2', 'TP53', 'CBLC',
       'TRAF7', 'WRN', 'TSC1', 'H3F3B', 'RAD21', 'HOOK3', 'EIF3E',
       'CHEK2', 'GPC5', 'SDC4', 'NRG1', 'MEN1', 'TPM3', 'PDE4DIP',
       'ARHGEF10L', 'BMP5', 'ABL1', 'TGFBR2', 'ARHGAP5', 'GATA2', 'MYD88',
       'NSD2', 'TFPT', 'BCL6', 'MACC1', 'AFDN', 'SEPT9', 'FGFR2', 'HRAS',
       'GMPS', 'CREB3L1', 'CDH1', 'TSC2', 'CDH11', 'ERBB2', 'CD74',
       'CDK6', 'PATZ1', 'PML', 'HGF', 'KRAS', 'IL7R', 'POLE', 'MRTFA',
       'CHCHD7', 'PDGFB', 'SDHAF2', 'WDCP', 'ACVR2A', 'NUP214', 'RPL5',
       'IRS4', 'PTPRT', 'DCTN1', 'SRSF3', 'KDM6A', 'RFWD3', 'SLC45A3',
       'NKX2-1', 'IDH1', 'ZNF384', 'BAP1', 'PTPRC', 'WWTR1', 'TCF7L2',
       'TPM4', 'NACA', 'CSMD3', 'PRKCB', 'CD209', 'PWWP2A', 'BRIP1',
       'CRTC3', 'XPC', 'STAT3', 'MAPK1', 'PDGFRA', 'CHIC2', 'IDH2',
       'MLLT10', 'ELF4', 'HNRNPA2B1', 'RET', 'TNFRSF14', 'ARID1B', 'RAC1',
       'JUN', 'NRAS', 'MUTYH', 'EPHA7', 'TNC', 'ZMYM3', 'KDM5A', 'BCOR',
       'POU2AF1', 'CARD11', 'BCL2', 'STAG1', 'SRSF2', 'FANCG', 'MPL',
       'PAX8', 'ETV6', 'CBFB', 'ECT2L', 'USP8', 'HERPUD1', 'HIF1A',
       'CLIP1', 'DICER1', 'TET2', 'PREX2', 'NOTCH2', 'CCND1', 'DDB2',
       'CCR7', 'USP6', 'TAF15', 'NSD3', 'NT5C2', 'POT1', 'FIP1L1', 'WIF1',
       'STK11', 'PLEC', 'FEN1', 'CAMTA1', 'POLR2A', 'CREB3L2', 'ANK1',
       'STAT5B', 'RMI2', 'USP9X', 'KIF5B', 'ZFHX3', 'ATIC', 'AXIN1',
       'CSF3R', 'NFIB', 'FOXO1', 'P2RY8', 'THRAP3', 'SEPT6', 'SND1',
       'BMPR1A', 'NIN', 'STIL', 'ZEB1', 'CYP2C8', 'MAX', 'AKT3', 'DEK',
       'TEC', 'PPP6C', 'ESR1', 'CYLD', 'SOS1', 'FGFR1', 'LEPROTL1',
       'BCLAF1', 'CDK4', 'RB1', 'USP44', 'PRDM2', 'RSPO2', 'NFKBIE',
       'ACSL3', 'AMER1', 'PRKACA', 'PPARG', 'BIRC3', 'ATP2B3', 'CACNA1D',
       'SETDB1', 'STAT6', 'PRDM16', 'REL', 'BCL11A', 'PTCH1', 'FES',
       'ARHGEF10', 'PPP2R1A', 'FCRL4', 'HOXC13', 'NBN', 'GOLPH3', 'PAX7',
       'SSX4', 'EXT1', 'ASXL1', 'MB21D2', 'CRNKL1', 'NTRK3', 'PIM1',
       'ZNF521', 'NBEA', 'GRIN2A', 'NR2F2', 'ERG', 'ERC1', 'GPC3', 'CNBP',
       'GPHN', 'LYN']

# %%
label_encoder = LabelEncoder()
label_encoder.fit_transform(df1["GENE_SYMBOL"])
# Out:
# array([381, 381, 381, ..., 380, 380, 380])

# %%
# Get min/max for numeric features
def get_minmax(col):
    return df[col].min(), df[col].max()

# Create numeric sliders / boxes
def create_numeric_input(name):
    min_val, max_val = get_minmax(name)
    return widgets.BoundedFloatText(
        value=(min_val + max_val) / 2,
        min=min_val,
        max=max_val,
        step=1.0,
        description=name,
        style={'description_width': 'initial'},
        layout=widgets.Layout(width='50%')
    )

AA_Length_Change = create_numeric_input("AA_Length_Change")
GENOME_START = create_numeric_input("GENOME_START")
GENOME_STOP = create_numeric_input("GENOME_STOP")
Gene_Encoded = create_numeric_input("Gene_Encoded")
Hydrophobicity_Change = create_numeric_input("Hydrophobicity_Change")
BLOSUM62_Score = create_numeric_input("BLOSUM62_Score")
Charge_Change = create_numeric_input("Charge_Change")
CHROMOSOME = create_numeric_input("CHROMOSOME")

mutation_type = widgets.Dropdown(
    options=mutation_type_options,
    description='Mutation Type:',
    style={'description_width': 'initial'},
    layout=widgets.Layout(width='50%')
)

somatic_status = widgets.Dropdown(
    options=somatic_status_options,
    description='Somatic Status:',
    style={'description_width': 'initial'},
    layout=widgets.Layout(width='50%')
)

gene_input = widgets.Text(
    value='TP53',
    placeholder='Enter gene symbol (e.g., TP53)',
    description='Gene:',
    style={'description_width': 'initial'},
    layout=widgets.Layout(width='50%')
)

# %%
predict_button = widgets.Button(
    description='Predict Mutation Pathogenicity',
    button_style='success',
    layout=widgets.Layout(width='50%')
)

output_box = widgets.Output()

def on_predict_clicked(b):
    with output_box:
        clear_output()

        # Initialize with medians
        row = df.median().copy()

        # Fill in user inputs
        row['AA_Length_Change'] = AA_Length_Change.value
        row['GENOME_START'] = GENOME_START.value
        row['GENOME_STOP'] = GENOME_STOP.value
        gene_name = gene_input.value.strip().upper()
        if gene_name not in gene_list:
            print(f"⚠️ '{gene_name}' is not a recognized gene. Please try again.")
            return
        row['Gene_Encoded'] = label_encoder.transform([gene_name])[0]
        row['Hydrophobicity_Change'] = Hydrophobicity_Change.value
        row['BLOSUM62_Score'] = BLOSUM62_Score.value
        row['Charge_Change'] = Charge_Change.value
        row['CHROMOSOME'] = CHROMOSOME.value

        # One-hot encode mutation type
        for cat in mutation_type_options:
            row[cat] = 1.0 if cat == mutation_type.value else 0.0

        # One-hot encode somatic status
        for status in somatic_status_options:
            col = f"MUTATION_SOMATIC_STATUS_{status}"
            if col in row:
                row[col] = 1.0 if status == somatic_status.value else 0.0

        # Select only the model input columns
        model_input = row[df.drop(columns='Label').columns].values.reshape(1, -1)

        # Predict
        prediction = rf.predict(model_input)[0]
        prob = rf.predict_proba(model_input)[0]

        label = "Pathogenic" if prediction == 1 else "Benign"
        confidence = np.max(prob) * 100

        print(f"🧬 Prediction: {label}")
        print(f"📊 Confidence: {confidence:.2f}%")

predict_button.on_click(on_predict_clicked)

# %%
form_items = widgets.VBox([
    mutation_type,
    somatic_status,
    CHROMOSOME,
    gene_input,
    AA_Length_Change,
    GENOME_START,
    GENOME_STOP,
    Hydrophobicity_Change,
    BLOSUM62_Score,
    Charge_Change,
    predict_button,
    output_box
])

display(form_items)
